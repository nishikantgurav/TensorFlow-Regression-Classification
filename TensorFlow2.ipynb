# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
#plt.fig(figsize=(10,6))
sns.distplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
#comparing label with features to see the correlation
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',legend=False)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
non_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,hue='price',legend=False)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,alpha=0.2,edgecolor=None,palette='RdYlGn')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df=df.drop('id',axis=1)

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date']=pd.to_datetime(df['date'])
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year']=df['date'].apply(lambda date:date.year)
df['month']=df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.drop('date',axis=1)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# ...

# %%
df.drop('zipcode',axis=1).head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X=df.drop(['price','date'],axis=1).values
y=df['price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
#preprocessing
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 20)

# %%
#model building
import tensorflow as tf
from tensorflow import keras
model=keras.models.Sequential(
    [keras.layers.Dense(20,activation='relu'),
    keras.layers.Dense(20,activation='relu'),
    keras.layers.Dense(20,activation='relu'),
    keras.layers.Dense(20,activation='relu'),
    keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam',loss='mse',metrics=['accuracy'])

# %%
model.fit(x=X_train,y=y_train.values,validation_data=(X_test,y_test.values),epochs=400)
model.history.history
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 2s 119us/sample - loss: 411267734127.3279 - accuracy: 0.0000e+00 - val_loss: 301718884321.6592 - val_accuracy: 0.0000e+00
# Epoch 2/400
# 15117/15117 [==============================] - 1s 71us/sample - loss: 140965540025.0611 - accuracy: 0.0000e+00 - val_loss: 95627996445.7086 - val_accuracy: 0.0000e+00
# Epoch 3/400
# 15117/15117 [==============================] - 1s 73us/sample - loss: 98519430749.2418 - accuracy: 0.0000e+00 - val_loss: 91073758569.5605 - val_accuracy: 0.0000e+00
# Epoch 4/400
# 15117/15117 [==============================] - 1s 77us/sample - loss: 92968758098.3867 - accuracy: 0.0000e+00 - val_loss: 86028185984.3161 - val_accuracy: 0.0000e+00
# Epoch 5/400
# 15117/15117 [==============================] - 1s 73us/sample - loss: 87008681913.2812 - accuracy: 0.0000e+00 - val_loss: 79557986582.1235 - val_accuracy: 0.0000e+00
# Epoch 6/400
# ...

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss  accuracy      val_loss  val_accuracy
# 0    4.112677e+11       0.0  3.017189e+11           0.0
# 1    1.409655e+11       0.0  9.562800e+10           0.0
# 2    9.851943e+10       0.0  9.107376e+10           0.0
# 3    9.296876e+10       0.0  8.602819e+10           0.0
# 4    8.700868e+10       0.0  7.955799e+10           0.0
# ..            ...       ...           ...           ...
# 395  1.699892e+10       0.0  1.815300e+10           0.0
# 396  1.693145e+10       0.0  1.809726e+10           0.0
# 397  1.696281e+10       0.0  1.807052e+10           0.0
# 398  1.690433e+10       0.0  1.804655e+10           0.0
# 399  1.691674e+10       0.0  1.818131e+10           0.0
#
# [400 rows x 4 columns]

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
predictions=model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 18181310717.1519

# %%
import numpy as np
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 134838.09075017305

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 80744.87530140817

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,predictions)

# %%
plt.plot(y_test,y_test,'r')

# %%
#prediction of brand new house
single_house=df.drop(['price','date'],axis=1).iloc[1]

# %%
single_house.values.reshape(-1,19)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-fdedd3c5f843> in <module>
# ----> 1 single_house.values.reshape(-1,19)
#
# ValueError: cannot reshape array of size 21 into shape (19)

# %%
single_house.values.reshape(-1,20)
# Out:
# array([[ 3.00000e+00,  2.25000e+00,  2.57000e+03,  7.24200e+03,
#          2.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  2.17000e+03,  4.00000e+02,  1.95100e+03,
#          1.99100e+03,  9.81250e+04,  4.77210e+01, -1.22319e+02,
#          1.69000e+03,  7.63900e+03,  2.01400e+03,  1.20000e+01]])

# %%
single_house=scaler.transform(single_house.values.reshape(-1,20))

# %%
model.predict(single_house)
# Out:
# array([[615092.25]], dtype=float32)

# %%
df.head(2)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# 0    98178  47.5112 -122.257           1340        5650  2014     10
# 1    98125  47.7210 -122.319           1690        7639  2014     12
#
# [2 rows x 22 columns]

# %%
#keras classification along EDA
df=pd.read_csv('cancer_classification.csv')
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
import seaborn as sns
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()['benign_0__mal_1'].sort_values()
# Out:
# worst concave points      -0.793566
# worst perimeter           -0.782914
# mean concave points       -0.776614
# worst radius              -0.776454
# mean perimeter            -0.742636
# worst area                -0.733825
# mean radius               -0.730029
# mean area                 -0.708984
# mean concavity            -0.696360
# worst concavity           -0.659610
# mean compactness          -0.596534
# worst compactness         -0.590998
# radius error              -0.567134
# perimeter error           -0.556141
# area error                -0.548236
# worst texture             -0.456903
# worst smoothness          -0.421465
# worst symmetry            -0.416294
# mean texture              -0.415185
# concave points error      -0.408042
# mean smoothness           -0.358560
# mean symmetry             -0.330499
# worst fractal dimension   -0.323872
# compactness error         -0.292999
# concavity error           -0.253730
# fractal dimension error   -0.077972
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X=df.drop('benign_0__mal_1',axis=1).values
y=df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (455, 30)

# %%
import tensorflow as tf
from tensorflow import keras
model=keras.models.Sequential(
    [keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),epochs=600)
model.history.history
# Out:
# Train on 455 samples, validate on 114 samples
# Epoch 1/600
# 455/455 [==============================] - 1s 3ms/sample - loss: 0.6719 - accuracy: 0.6484 - val_loss: 0.6367 - val_accuracy: 0.7544
# Epoch 2/600
# 455/455 [==============================] - 0s 259us/sample - loss: 0.6191 - accuracy: 0.7890 - val_loss: 0.5805 - val_accuracy: 0.8246
# Epoch 3/600
# 455/455 [==============================] - 0s 132us/sample - loss: 0.5697 - accuracy: 0.8374 - val_loss: 0.5315 - val_accuracy: 0.8509
# Epoch 4/600
# 455/455 [==============================] - 0s 117us/sample - loss: 0.5241 - accuracy: 0.8615 - val_loss: 0.4854 - val_accuracy: 0.8596
# Epoch 5/600
# 455/455 [==============================] - 0s 121us/sample - loss: 0.4793 - accuracy: 0.8725 - val_loss: 0.4403 - val_accuracy: 0.8596
# Epoch 6/600
# 455/455 [==============================] - 0s 109us/sample - loss: 0.4379 - accuracy: 0.8791 - val_loss: 0.3958 - val_accuracy: 0.8596
# Epoch 7/600
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss',mode='min',patience=25)

# %%
import tensorflow as tf
from tensorflow import keras
model=keras.models.Sequential(
    [keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),epochs=600,callbacks=[early_stop])
# Out:
# Train on 455 samples, validate on 114 samples
# Epoch 1/600
# 455/455 [==============================] - 1s 3ms/sample - loss: 0.6968 - val_loss: 0.6753
# Epoch 2/600
# 455/455 [==============================] - 0s 135us/sample - loss: 0.6590 - val_loss: 0.6398
# Epoch 3/600
# 455/455 [==============================] - 0s 93us/sample - loss: 0.6247 - val_loss: 0.6027
# Epoch 4/600
# 455/455 [==============================] - 0s 111us/sample - loss: 0.5882 - val_loss: 0.5599
# Epoch 5/600
# 455/455 [==============================] - 0s 118us/sample - loss: 0.5481 - val_loss: 0.5153
# Epoch 6/600
# 455/455 [==============================] - 0s 104us/sample - loss: 0.5051 - val_loss: 0.4658
# Epoch 7/600
# 455/455 [==============================] - 0s 101us/sample - loss: 0.4539 - val_loss: 0.4066
# Epoch 8/600
# 455/455 [==============================] - 0s 125us/sample - loss: 0.3996 - val_loss: 0.3603
# Epoch 9/600
# ...

# %%
model_loss=pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
import tensorflow as tf
from tensorflow import keras
model=keras.models.Sequential(
    [keras.layers.Dense(30,activation='relu'),
     keras.layers.Dropout(0.5),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),epochs=600,callbacks=[early_stop])
# Out:
# Train on 455 samples, validate on 114 samples
# Epoch 1/600
# 455/455 [==============================] - 1s 2ms/sample - loss: 0.6993 - val_loss: 0.6502
# Epoch 2/600
# 455/455 [==============================] - 0s 121us/sample - loss: 0.6508 - val_loss: 0.6138
# Epoch 3/600
# 455/455 [==============================] - 0s 100us/sample - loss: 0.6288 - val_loss: 0.5749
# Epoch 4/600
# 455/455 [==============================] - 0s 100us/sample - loss: 0.5785 - val_loss: 0.5312
# Epoch 5/600
# 455/455 [==============================] - 0s 99us/sample - loss: 0.5477 - val_loss: 0.4855
# Epoch 6/600
# 455/455 [==============================] - 0s 102us/sample - loss: 0.5210 - val_loss: 0.4439
# Epoch 7/600
# 455/455 [==============================] - 0s 114us/sample - loss: 0.5041 - val_loss: 0.4074
# Epoch 8/600
# 455/455 [==============================] - 0s 101us/sample - loss: 0.4495 - val_loss: 0.3863
# Epoch 9/600
# ...

# %%
model_loss=pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
predictions=model.predict_classes(X_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,predictions)
score
# Out:
# 0.9912280701754386
